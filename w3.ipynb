# %% [markdown]
# W3A1

# %%
n = int(input())
donVi = n % 10
hangNghin = (n//1000) % 10
print("don vi la:", donVi)
print(f"don vi la: {donVi}")
print("hang nghin la:", hangNghin)
# Out:
# don vi la: 5
# don vi la: 5
# hang nghin la: 2

# %% [markdown]
# W3A2. Hoán đổi 2 số Không dùng biến tạm thời.

# %%
a, b = map(int, input().split())
a, b = b, a

# %% [markdown]
# W3A3

# %%
n = int(input())
if n > 0 and (n &(n-1) == 0):
    print(f"{n} La luy thua cua 2 ")
else:
    print(f"{n} Khong la luy thua cua 2")
# Out:
# 16 La luy thua cua 2

# %% [markdown]
# W3A4. Viết chương trình một số m chia n, làm tròn xuống.

# %%
m, n = float(input())
chia = m / n
print(f"{chia}:.3f")
a = chia * 10**3

# %% [markdown]
# W3A5.

# %% [markdown]
# W3A10.

# %%
m, n, p, q = map(int, input().split())
_max = n
if m> _max:
    _max = m
if p> _max:
    _max = p
if q> _max:
    _max = q
print(_max)
# Out:
# 6
