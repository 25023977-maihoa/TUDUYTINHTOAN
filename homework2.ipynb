# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntích và chu vi của nó.

# %%
a, b = map (float, input().split())
dien_tich = a * b
chu_vi = (a+b) / 2
print(dien_tich)
print(chu_vi)
# Out:
# 18.0
# 4.5

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó

# %%
r = float(input())
dien_tich = 3.14 * r ** 2
chu_vi = 3.14* 2 * r
print("Dien tich la:", dien_tich)
print(f"Chu vi la: {chu_vi:.2f}")
# Out:
# Dien tich la: 78.5
# Chu vi la: 31.40

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a, b, c = map (float, input().split())
if a+b>c and a+c>b and b+c>a:
    print("La ba canh cua mot tam giac")
    if a == b == c:
        print("La tam giac deu")
    elif a==b or b==c or a==c:
        print("La tam giac can")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
        print("La tam giac vuong")
    else:
        print("La tam giac thuong")
else:
    print("Khong la ba canh cua mot tam giac")
# Out:
# La ba canh cua mot tam giac
# La tam giac thuong

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b = map(float, input().split())
x = -b/a
print(x)
# Out:
# -1.6

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c = map(float, input().split())
if a==0:
    if

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, d được nhập từ bànphím).

# %%
a, b, c, d = map(float, input().split())
gia_tri_lon_nhat = max(a,b,c,d)
print("Giá trị lớn nhất là:", gia_tri_lon_nhat)
# Out:
# Giá trị lớn nhất là: 9.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d = map(float, input().split())
gia_tri_nho_nhat =min(a,b,c,d)
print("Giá trị nhỏ nhất là:", gia_tri_nho_nhat)
# Out:
# Giá trị nhỏ nhất là: -0.2

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax + by = m
# cx + dy = n

# %%
a, b, c, d, m, n = map(int, input().split())
if a == c and b==d and m==n or c/a == d/b == n/m:
    print("Vô số nghiệm")
elif a==c and b==d and m!=n:
    print("Vô nghiệm")
elif a==b==0 and m!=0 or c==d==0 and n!=0:
    print("Vô nghiệm")
else:
    y = (a*n-c*m)/(a*d-b*c)
    x = (m-b*y)/a 
    print(f"Nghiệm của hệ phương trình là: x = {x} \n y = {y}")
chưa xong
# Out:
# Nghiệm của hệ phương trình là: x = 1.2
#  y = 0.4

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = int(input())
gio = x//3600
phut = (x%3600)//60 
giay = x % 60
print(f"{gio} giờ, {phut} phút, {giay} giây ")
# Out:
# 0 giờ, 14 phút, 50 giây

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a, b, x, y = map(int,input().split())
ban_kinh = r
r**2 = (x-a)**2 + (y-b)**2

# %% [markdown]
# Bài 11: Tính x^y (Với x, y là số thực)

# %%
x, y = map(float, input().split())
a = x**y
print(a)
# Out:
# 16.0
